# %%
#штакельберг 1 агент принуждение
#Штакельбер обычный - 1 агент
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
start = time.time()

#объявление переменных
N = 10
T_min = 5000 #супервайзер u  (5000-7000)
T_max = 7000
tao_min = 0.1 #агент v
tao_max = 1

h_T = (T_max - T_min)/N
#h_tao = (tao_max - tao_min)/N
z0 = 0.1
z_abs = 0.5 #то с чем сравниваем - наш показатель "эффективности" - идеальный 
a = 0.8 #коэфф
#m1 = 1 #коэфф
outlay = 0.007
lambd = - 100000
lambd_1 = -100 
salary = 10000
k_c = 7
bet = 0.5
#определяем функции - тестовые 
def J_0(T, tao, z):
    return (T * tao) * 0.8 * (1 - z) - outlay - lambd * (T ** lambd_1)
def J_1(T, tao, z):
    return 0.87 * salary * ((1 + z) ** 2) - tao * T * (1 - z) + k_c * (z**bet) * ((tao_max - tao)**(1 - bet))
def z_tao(tao):
    return round(z0 + a * tao, 5)


def Shtackelberg_1_pr():
    #цикл
    J0_list = []
    for i_T in range (N):
        T = T_min + i_T * h_T
        h_tao = (tao_max - T/10000)/N
        J1_list = []

        for i_tao in range (N):
            tao = T/10000 + i_tao * h_tao
            J1_list.append(round(J_1(T, tao, z_tao(tao)), 7))
        J1_max = max(J1_list)
        tao_ind = round (J1_list.index(J1_max) * h_tao + tao_min, 7) #нашли tao при котором достигается максимум

        print("все значения функции ведомого для данного T", J1_list)
        print("max", max(J1_list)) 
        print("tao при котором max", tao_ind, "индекс этого элемента", J1_list.index(J1_max))
        print("значение показателя", z_tao(tao_ind))


        if z_tao(tao_ind) > z_abs:
            print("cool")
            J0_list.append(round(J_0(T, tao_ind, z_tao(tao_ind)), 7))
            print("значение z при оптимальном tao", z_tao(tao_ind) )
        else:
            print("fale") #если не выполняется уcловие 4 мы должны поменять управление то есть просто переход не след.шаг цикла по Т
            print("*************************************")
            continue 
        print(T) #из-за continue должен печатать только те T, которые удовлетворяют условию 4
        print("*************************************")


    print("все полученные значения J_0")   
    print(J0_list)  
    print('значение целевой функции супервайзера', max(J0_list))
    print ('время выполнения программы:', time.time() - start, 'секунд')
    print('коэффициент согласованности', round(max(J0_list)/J_0(T_max, tao_max, z0), 5))
    
Shtackelberg_1_pr()
# Out:
# все значения функции ведомого для данного T [18328.5, 19371.3706521, 20462.0516465, 21600.5408281, 22786.8348034, 24020.9283101, 25302.8129538, 26632.4743684, 28009.8844949, 29434.9715509]
# max 29434.9715509
# tao при котором max 0.55 индекс этого элемента 9
# значение показателя 0.54
# cool
# значение z при оптимальном tao 0.54
# 5000.0
# *************************************
# все значения функции ведомого для данного T [18689.5749221, 19707.8879893, 20770.9997472, 21878.9079624, 23031.6092189, 24229.0982948, 25471.3669224, 26758.4010077, 28090.1730724, 29466.612858]
# max 29466.612858
# tao при котором max 0.532 индекс этого элемента 9
# значение показателя 0.5256
# cool
# значение z при оптимальном tao 0.5256
# 5200.0
# *************************************
# все значения функции ведомого для данного T [19057.8836428, 20050.7685108, 21085.4730814, 22161.9950671, 23280.3310471, 24440.4758549, 25642.4213621, 26886.1537592, 28171.6461644, 29498.8298746]
# max 29498.8298746
# tao при котором max 0.514 индекс этого элемента 9
# значение показателя 0.5112
# cool
# значение z при оптимальном tao 0.5112
# 5400.0
# *************************************
# все значения функции ведомого для данного T [19433.810078, 20400.3231556, 21405.7173012, 22449.9901934, 23533.1384234, 24655.1568929, 25816.0376252, 27015.7671072, 28254.31907, 29531.6263982]
# max 29531.6263982
# tao при котором max 0.496 индекс этого элемента 9
# значение показателя 0.4968
# fale
# *************************************
# все значения функции ведомого для данного T [19817.7381224, 20756.8628447, 21731.9780424, 22743.0813784, 23790.1694701, 24873.2373, 25992.2770539, 27147.2755276, 28338.2070812, 29565.0062214]
# max 29565.0062214
# tao при котором max 0.478 индекс этого элемента 9
# значение показателя 0.4824
# fale
# *************************************
# все значения функции ведомого для данного T [20210.0516465, 21120.698478, 22064.5009225, 23041.4566425, 24051.5622948, 25094.8129538, 26171.2009789, 27280.7134861, 28423.3254817, 29598.9731312]
# max 29598.9731312
# tao при котором max 0.46 индекс этого элемента 9
# значение показателя 0.468
# fale
# *************************************
# все значения функции ведомого для данного T [20611.134494, 21492.140932, 22403.5315375, 23345.3039869, 24317.4549875, 25319.9797164, 26352.8707166, 27416.1154366, 28509.6895461, 29633.530908]
# max 29633.530908
# tao при котором max 0.442 индекс этого элемента 9
# значение показателя 0.4536
# fale
# *************************************
# все значения функции ведомого для данного T [21021.370478, 21871.5010555, 22749.3154589, 23654.8113901, 24587.985618, 25548.8334316, 26537.3475677, 27553.515819, 28597.3145372, 29668.6833241]
# max 29668.6833241
# tao при котором max 0.424 индекс этого элемента 9
# значение показателя 0.4392
# fale
# *************************************
# все значения функции ведомого для данного T [21441.1433757, 22259.0896651, 23102.0982283, 23970.1668037, 24863.2922311, 25781.4699208, 26724.6928129, 27692.9490566, 28686.2157047, 29704.4341424]
# max 29704.4341424
# tao при котором max 0.406 индекс этого элемента 9
# значение показателя 0.4248
# fale
# *************************************
# все значения функции ведомого для данного T [21870.8369225, 22655.2175389, 23462.1253523, 24291.558147, 25143.5128424, 26017.9849789, 26914.9677095, 27834.4495524, 28776.4082817, 29740.7871144]
# max 29740.7871144
# tao при котором max 0.388 индекс этого элемента 9
# значение показателя 0.4104
# fale
# *************************************
# все полученные значения J_0
# [1011.993, 1049.897128, 1085.363624]
# значение целевой функции супервайзера 1085.363624
# время выполнения программы: 0.0029981136322021484 секунд
# коэффициент согласованности 0.21535
