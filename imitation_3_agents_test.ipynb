# %%
#обычный Штакельберг, 3 агента - используем равновесие Нэша
import numpy as np

#объявление переменных
N_ag = 3

N_1, N_2, N_3 = 4, 4, 4    #по агентам - u       
M_1, M_2, M_3 = 4, 4, 4    #по супервайзеру - v

v1_min, v2_min, v3_min = 1, 2, 3 
v1_max, v2_max, v3_max = 10, 20, 30

u1_min, u2_min, u3_min = 5, 7, 9 
u1_max, u2_max, u3_max = 25, 45, 65

h_v1 = round((v1_max - v1_min)/M_1, 3)
h_v2 = round((v2_max - v2_min)/M_2, 3)
h_v3 = round((v3_max - v3_min)/M_3, 3)

h_u1 = round((u1_max - u1_min)/N_1, 3)
h_u2 = round((u2_max - u2_min)/N_2, 3)
h_u3 = round((u3_max - u3_min)/N_3, 3)

z0 = 10
z_abs = 70 #то с чем сравниваем - наш показатель "эффективности" - идеальный 

#определяем функции - тестовые 
def J_0(v1, v2, v3, u1, u2, u3):
    return round((v1 + u1) ** 2 + (v2 + u2) * (v2 + u2) / (v2 ** 2 + u2 ** 2) + v3 * u3, 5)
def J1_1(v1, u1):
    return round(v1 ** 3 * u1, 5)
def J1_2(v2, u2):
    return round(v2 * u2, 5)
def J1_3(v3, u3):
    return round(v3 * u3 ** 3, 5)
def z_current(v1, v2, v3, u1, u2, u3):
     return round(z0 + u1 * u2 * u3 / (v1 + v2 + v3), 5)
    
#имитация

print('шаги')
print (h_v1, h_v2, h_v3, h_u1, h_u2, h_u3)
qt = 0 #"номер комбинации управлений" - счетчик для проверки
#так как кажому значению функции соответстует набор управлени для хранения наборов, которые яляются 
#равновесиями Нэша можно использовать словарь вида {key_qt: [J1, J2, J3, v1, v2, v3, u1, u2, u3]}
#НО!!! если равновесий Нэша несколько, могут ли целевые функции одного агента для разных равновесий быть равны?? 
Ji_Nash_dic = {}

J0_lst = []
for i_v1 in range (0, M_1):
    v1 = round(v1_min + i_v1 * h_v1, 5)
    for i_v2 in range (0, M_2):
        v2 = round(v2_min + i_v2 * h_v2, 5)
        for i_v3 in range (0, M_3):
            v3 = round(v3_min + i_v3 * h_v3, 5)
            print("набор управлений супервайзера:", v1, v2, v3)
            
            #после нэша в этом цикле проверить целевую ф ведущего - зафиксируем управления ведомых
            #и теперь перебираем по управлениям ведущего
            
            J1_lst = []
            for i_u1 in range (0, N_1):
                u1 = round(u1_min + i_u1 * h_u1, 5)
                J2_lst = []
                for i_u2 in range (0, N_2):               
                    u2 = round(u2_min + i_u2 * h_u2, 5)
                    J3_lst = []
                    for i_u3 in range (0, N_3):
                        u3 = round(u3_min + i_u3 * h_u3, 5)
                        print("набор управлений агентов:", u1, u2, u3)
                        qt += 1
                        print(qt)
                
                        J3_lst.append(round(J1_3(v3, u3), 5))
                        J1_lst.append(round(J1_1(v1, u1), 5))
                        J2_lst.append(round(J1_2(v2, u2), 5))
                        
                        

                        #проверка на Нэша для всех Ji                      
                        J1_Nash_lst = []
                        J2_Nash_lst = []
                        J3_Nash_lst = []
                        
                        max_J1 = max(J1_lst)
                        max_J2 = max(J2_lst)
                        max_J3 = max(J3_lst)
                        print('max J1', max_J1, 'max J2', max_J2, 'max J3', max_J3)
   
                        Nash =  True #флаг
                        
                        for k_1 in range (0, N_1): 
                            u1_n = round(u1_min + k_1 * h_u1, 5)
                            J1_Nash_lst.append(round(J1_1(v1, u1_n), 5))
                        print('набор значений J1 по управлениям',v1, v2, v3, 'u1_n', u2, u3, 'выглядит следующим образом:', J1_Nash_lst)
                        max_J1_Nash = max(J1_Nash_lst)
                        print(max_J1_Nash)
                        
                        if  max_J1_Nash > max_J1:
                            Nash = False
                            print('переходим к следующему шагу из-за J1')
                            
                        if Nash:    
                            for k_2 in range (0, N_2): 
                                u2_n = round(u2_min + k_2 * h_u2, 5)
                                J2_Nash_lst.append(round(J1_2(v2, u2_n), 5))
                            print('набор значений J2 по управлениям',v1, v2, v3, u1, 'u2_n', u3, 'выглядит:', J2_Nash_lst)
                            max_J2_Nash = max(J2_Nash_lst)
                            if  max_J2_Nash > max_J2:
                                Nash = False 
                                print('переходим к следующему шагу из-за J2')
                               
                        if Nash:
                            for k_3 in range (0, N_3): 
                                u3_n = round(u3_min + k_3 * h_u3, 5)
                                J3_Nash_lst.append(round(J1_3(v3, u3_n), 5))
                            print('набор значений J3 по управлениям',v1, v2, v3, u1, u2, 'u3_n', 'равен:',  J1_Nash_lst)
                            max_J3_Nash = max(J3_Nash_lst)
                            if  max_J3_Nash > max_J3:
                                Nash = False  
                                print('переходим к следующему шагу из-за J3')
                                
                        #если условия выполнены - добавляем в наш словарь
                        
                        
                        
                        
                        if Nash:
                            if qt not in Ji_Nash_dic.keys():
                                Ji_Nash_dic[qt] = [max_J1, max_J2, max_J3, v1, v2, v3, u1, u2, u3]
                            print("значение z при оптимальных управлениях", z_current(v1, v2, v3, u1, u2, u3))
                            if z_current(v1, v2, v3, u1, u2, u3) < z_abs:
                                print("fale_z_current") #если не выполняется уловие 4 мы должны поменять управление то есть просто переход не след.шаг цикла по Т

    
                               
                        print(Nash)
                        print('******************************************************************')
            print('J1:', J1_lst)   
            print('J2:', J2_lst) 
            print('J3:', J3_lst)                
                                    
print ('общее количество вариантов наборов управлений', qt) 
for item in Ji_Nash_dic.keys():
    print (item, ':', Ji_Nash_dic[item])
    #словари не упорядочены по порядку(ключу), поэтому печать не зависит от порядкового номера
print('количество равновесий:', len(Ji_Nash_dic))   

#теперь на основе этого набора значений, которые подходят агентам находим минимум для супервайзера. Его гарантированный выигрыш
J0_dic = {} 
for item in Ji_Nash_dic.keys():
    if item not in J0_dic.keys():
        #J_0(v1, v2, v3, u1, u2, u3):
        J0_dic[item] = J_0(Ji_Nash_dic[item][3], Ji_Nash_dic[item][4], Ji_Nash_dic[item][5], Ji_Nash_dic[item][6], Ji_Nash_dic[item][7], Ji_Nash_dic[item][8])
    
print('значения целевой ф. ведущего', J0_dic)    
print('min J0_dic', min(J0_dic.values()))   
min_J0 = min(J0_dic.values())
#проверка на совпадение значений: если несколько одинаковых J0 для разных наборов управлений - печатаем все
for item in J0_dic.keys():
    if J0_dic[item] == min_J0:
        print(item, 'набор управлений:', Ji_Nash_dic[item][3], Ji_Nash_dic[item][4], Ji_Nash_dic[item][5], Ji_Nash_dic[item][6], Ji_Nash_dic[item][7], Ji_Nash_dic[item][8])
        print('для этого набора значение показателя равно:', z_current(v1, v2, v3, u1, u2, u3))
# Out:
# шаги
# 2.25 4.5 6.75 5.0 9.5 14.0
# набор управлений супервайзера: 1.0 2.0 3.0
# набор управлений агентов: 5.0 7.0 9.0
# 1
# max J1 5.0 max J2 14.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 7.0 23.0
# 2
# max J1 5.0 max J2 14.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 7.0 37.0
# 3
# max J1 5.0 max J2 14.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 7.0 51.0
# 4
# max J1 5.0 max J2 14.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 9.0
# 5
# max J1 5.0 max J2 33.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 23.0
# 6
# max J1 5.0 max J2 33.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 37.0
# 7
# max J1 5.0 max J2 33.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 51.0
# 8
# max J1 5.0 max J2 33.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 26.0 9.0
# 9
# max J1 5.0 max J2 52.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 26.0 23.0
# 10
# max J1 5.0 max J2 52.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 26.0 37.0
# 11
# max J1 5.0 max J2 52.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 26.0 51.0
# 12
# max J1 5.0 max J2 52.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 35.5 9.0
# 13
# max J1 5.0 max J2 71.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 35.5 23.0
# 14
# max J1 5.0 max J2 71.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 35.5 37.0
# 15
# max J1 5.0 max J2 71.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 35.5 51.0
# 16
# max J1 5.0 max J2 71.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 7.0 9.0
# 17
# max J1 10.0 max J2 14.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 7.0 23.0
# 18
# max J1 10.0 max J2 14.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 7.0 37.0
# 19
# max J1 10.0 max J2 14.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 7.0 51.0
# 20
# max J1 10.0 max J2 14.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 16.5 9.0
# 21
# max J1 10.0 max J2 33.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 16.5 23.0
# 22
# max J1 10.0 max J2 33.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 16.5 37.0
# 23
# max J1 10.0 max J2 33.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 16.5 51.0
# 24
# max J1 10.0 max J2 33.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 26.0 9.0
# 25
# max J1 10.0 max J2 52.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 26.0 23.0
# 26
# max J1 10.0 max J2 52.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 26.0 37.0
# 27
# max J1 10.0 max J2 52.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 26.0 51.0
# 28
# max J1 10.0 max J2 52.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 35.5 9.0
# 29
# max J1 10.0 max J2 71.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 35.5 23.0
# 30
# max J1 10.0 max J2 71.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 35.5 37.0
# 31
# max J1 10.0 max J2 71.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 35.5 51.0
# 32
# max J1 10.0 max J2 71.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 7.0 9.0
# 33
# max J1 15.0 max J2 14.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 7.0 23.0
# 34
# max J1 15.0 max J2 14.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 7.0 37.0
# 35
# max J1 15.0 max J2 14.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 7.0 51.0
# 36
# max J1 15.0 max J2 14.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 16.5 9.0
# 37
# max J1 15.0 max J2 33.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 16.5 23.0
# 38
# max J1 15.0 max J2 33.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 16.5 37.0
# 39
# max J1 15.0 max J2 33.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 16.5 51.0
# 40
# max J1 15.0 max J2 33.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 26.0 9.0
# 41
# max J1 15.0 max J2 52.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 26.0 23.0
# 42
# max J1 15.0 max J2 52.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 26.0 37.0
# 43
# max J1 15.0 max J2 52.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 26.0 51.0
# 44
# max J1 15.0 max J2 52.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 35.5 9.0
# 45
# max J1 15.0 max J2 71.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 35.5 23.0
# 46
# max J1 15.0 max J2 71.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 35.5 37.0
# 47
# max J1 15.0 max J2 71.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 35.5 51.0
# 48
# max J1 15.0 max J2 71.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 9.0
# 49
# max J1 20.0 max J2 14.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 9.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 23.0
# 50
# max J1 20.0 max J2 14.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 23.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 37.0
# 51
# max J1 20.0 max J2 14.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 37.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 51.0
# 52
# max J1 20.0 max J2 14.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 7.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 51.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 9.0
# 53
# max J1 20.0 max J2 33.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 9.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 23.0
# 54
# max J1 20.0 max J2 33.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 23.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 37.0
# 55
# max J1 20.0 max J2 33.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 37.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 51.0
# 56
# max J1 20.0 max J2 33.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 16.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 51.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 9.0
# 57
# max J1 20.0 max J2 52.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 9.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 23.0
# 58
# max J1 20.0 max J2 52.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 23.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 37.0
# 59
# max J1 20.0 max J2 52.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 37.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 51.0
# 60
# max J1 20.0 max J2 52.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 26.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 51.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 9.0
# 61
# max J1 20.0 max J2 71.0 max J3 2187.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 9.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# набор значений J3 по управлениям 1.0 2.0 3.0 20.0 35.5 u3_n равен: [5.0, 10.0, 15.0, 20.0]
# переходим к следующему шагу из-за J3
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 23.0
# 62
# max J1 20.0 max J2 71.0 max J3 36501.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 23.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# набор значений J3 по управлениям 1.0 2.0 3.0 20.0 35.5 u3_n равен: [5.0, 10.0, 15.0, 20.0]
# переходим к следующему шагу из-за J3
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 37.0
# 63
# max J1 20.0 max J2 71.0 max J3 151959.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 37.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# набор значений J3 по управлениям 1.0 2.0 3.0 20.0 35.5 u3_n равен: [5.0, 10.0, 15.0, 20.0]
# переходим к следующему шагу из-за J3
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 51.0
# 64
# max J1 20.0 max J2 71.0 max J3 397953.0
# набор значений J1 по управлениям 1.0 2.0 3.0 u1_n 35.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 3.0 20.0 u2_n 51.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# набор значений J3 по управлениям 1.0 2.0 3.0 20.0 35.5 u3_n равен: [5.0, 10.0, 15.0, 20.0]
# значение z при оптимальных управлениях 6045.0
# True
# ******************************************************************
# J1: [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0]
# J2: [14.0, 14.0, 14.0, 14.0, 33.0, 33.0, 33.0, 33.0, 52.0, 52.0, 52.0, 52.0, 71.0, 71.0, 71.0, 71.0]
# J3: [2187.0, 36501.0, 151959.0, 397953.0]
# набор управлений супервайзера: 1.0 2.0 9.75
# набор управлений агентов: 5.0 7.0 9.0
# 65
# max J1 5.0 max J2 14.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 7.0 23.0
# 66
# max J1 5.0 max J2 14.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 7.0 37.0
# 67
# max J1 5.0 max J2 14.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 7.0 51.0
# 68
# max J1 5.0 max J2 14.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 9.0
# 69
# max J1 5.0 max J2 33.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 23.0
# 70
# max J1 5.0 max J2 33.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 37.0
# 71
# max J1 5.0 max J2 33.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 51.0
# 72
# max J1 5.0 max J2 33.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 26.0 9.0
# 73
# max J1 5.0 max J2 52.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 26.0 23.0
# 74
# max J1 5.0 max J2 52.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 26.0 37.0
# 75
# max J1 5.0 max J2 52.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 26.0 51.0
# 76
# max J1 5.0 max J2 52.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 35.5 9.0
# 77
# max J1 5.0 max J2 71.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 35.5 23.0
# 78
# max J1 5.0 max J2 71.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 35.5 37.0
# 79
# max J1 5.0 max J2 71.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 35.5 51.0
# 80
# max J1 5.0 max J2 71.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 7.0 9.0
# 81
# max J1 10.0 max J2 14.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 7.0 23.0
# 82
# max J1 10.0 max J2 14.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 7.0 37.0
# 83
# max J1 10.0 max J2 14.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 7.0 51.0
# 84
# max J1 10.0 max J2 14.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 16.5 9.0
# 85
# max J1 10.0 max J2 33.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 16.5 23.0
# 86
# max J1 10.0 max J2 33.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 16.5 37.0
# 87
# max J1 10.0 max J2 33.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 16.5 51.0
# 88
# max J1 10.0 max J2 33.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 26.0 9.0
# 89
# max J1 10.0 max J2 52.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 26.0 23.0
# 90
# max J1 10.0 max J2 52.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 26.0 37.0
# 91
# max J1 10.0 max J2 52.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 26.0 51.0
# 92
# max J1 10.0 max J2 52.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 35.5 9.0
# 93
# max J1 10.0 max J2 71.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 35.5 23.0
# 94
# max J1 10.0 max J2 71.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 35.5 37.0
# 95
# max J1 10.0 max J2 71.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 10.0 35.5 51.0
# 96
# max J1 10.0 max J2 71.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 7.0 9.0
# 97
# max J1 15.0 max J2 14.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 7.0 23.0
# 98
# max J1 15.0 max J2 14.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 7.0 37.0
# 99
# max J1 15.0 max J2 14.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 7.0 51.0
# 100
# max J1 15.0 max J2 14.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 16.5 9.0
# 101
# max J1 15.0 max J2 33.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 16.5 23.0
# 102
# max J1 15.0 max J2 33.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 16.5 37.0
# 103
# max J1 15.0 max J2 33.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 16.5 51.0
# 104
# max J1 15.0 max J2 33.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 26.0 9.0
# 105
# max J1 15.0 max J2 52.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 26.0 23.0
# 106
# max J1 15.0 max J2 52.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 26.0 37.0
# 107
# max J1 15.0 max J2 52.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 26.0 51.0
# 108
# max J1 15.0 max J2 52.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 35.5 9.0
# 109
# max J1 15.0 max J2 71.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 35.5 23.0
# 110
# max J1 15.0 max J2 71.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 35.5 37.0
# 111
# max J1 15.0 max J2 71.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 35.5 51.0
# 112
# max J1 15.0 max J2 71.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 9.0
# 113
# max J1 20.0 max J2 14.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 9.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 23.0
# 114
# max J1 20.0 max J2 14.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 23.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 37.0
# 115
# max J1 20.0 max J2 14.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 37.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 51.0
# 116
# max J1 20.0 max J2 14.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 7.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 51.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 9.0
# 117
# max J1 20.0 max J2 33.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 9.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 23.0
# 118
# max J1 20.0 max J2 33.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 23.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 37.0
# 119
# max J1 20.0 max J2 33.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 37.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 51.0
# 120
# max J1 20.0 max J2 33.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 16.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 51.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 9.0
# 121
# max J1 20.0 max J2 52.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 9.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 23.0
# 122
# max J1 20.0 max J2 52.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 23.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 37.0
# 123
# max J1 20.0 max J2 52.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 37.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 51.0
# 124
# max J1 20.0 max J2 52.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 26.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 51.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 9.0
# 125
# max J1 20.0 max J2 71.0 max J3 7107.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 9.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# набор значений J3 по управлениям 1.0 2.0 9.75 20.0 35.5 u3_n равен: [5.0, 10.0, 15.0, 20.0]
# переходим к следующему шагу из-за J3
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 23.0
# 126
# max J1 20.0 max J2 71.0 max J3 118628.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 23.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# набор значений J3 по управлениям 1.0 2.0 9.75 20.0 35.5 u3_n равен: [5.0, 10.0, 15.0, 20.0]
# переходим к следующему шагу из-за J3
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 37.0
# 127
# max J1 20.0 max J2 71.0 max J3 493866.75
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 37.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# набор значений J3 по управлениям 1.0 2.0 9.75 20.0 35.5 u3_n равен: [5.0, 10.0, 15.0, 20.0]
# переходим к следующему шагу из-за J3
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 51.0
# 128
# max J1 20.0 max J2 71.0 max J3 1293347.25
# набор значений J1 по управлениям 1.0 2.0 9.75 u1_n 35.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# набор значений J2 по управлениям 1.0 2.0 9.75 20.0 u2_n 51.0 выглядит: [14.0, 33.0, 52.0, 71.0]
# набор значений J3 по управлениям 1.0 2.0 9.75 20.0 35.5 u3_n равен: [5.0, 10.0, 15.0, 20.0]
# значение z при оптимальных управлениях 2850.0
# True
# ******************************************************************
# J1: [5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 5.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0]
# J2: [14.0, 14.0, 14.0, 14.0, 33.0, 33.0, 33.0, 33.0, 52.0, 52.0, 52.0, 52.0, 71.0, 71.0, 71.0, 71.0]
# J3: [7107.75, 118628.25, 493866.75, 1293347.25]
# набор управлений супервайзера: 1.0 2.0 16.5
# набор управлений агентов: 5.0 7.0 9.0
# 129
# max J1 5.0 max J2 14.0 max J3 12028.5
# набор значений J1 по управлениям 1.0 2.0 16.5 u1_n 7.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 7.0 23.0
# 130
# max J1 5.0 max J2 14.0 max J3 200755.5
# набор значений J1 по управлениям 1.0 2.0 16.5 u1_n 7.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 7.0 37.0
# 131
# max J1 5.0 max J2 14.0 max J3 835774.5
# набор значений J1 по управлениям 1.0 2.0 16.5 u1_n 7.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 7.0 51.0
# 132
# max J1 5.0 max J2 14.0 max J3 2188741.5
# набор значений J1 по управлениям 1.0 2.0 16.5 u1_n 7.0 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 9.0
# 133
# max J1 5.0 max J2 33.0 max J3 12028.5
# набор значений J1 по управлениям 1.0 2.0 16.5 u1_n 16.5 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 23.0
# 134
# max J1 5.0 max J2 33.0 max J3 200755.5
# набор значений J1 по управлениям 1.0 2.0 16.5 u1_n 16.5 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 37.0
# 135
# max J1 5.0 max J2 33.0 max J3 835774.5
# набор значений J1 по управлениям 1.0 2.0 16.5 u1_n 16.5 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 16.5 51.0
# 136
# max J1 5.0 max J2 33.0 max J3 2188741.5
# набор значений J1 по управлениям 1.0 2.0 16.5 u1_n 16.5 51.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 26.0 9.0
# 137
# max J1 5.0 max J2 52.0 max J3 12028.5
# набор значений J1 по управлениям 1.0 2.0 16.5 u1_n 26.0 9.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 26.0 23.0
# 138
# max J1 5.0 max J2 52.0 max J3 200755.5
# набор значений J1 по управлениям 1.0 2.0 16.5 u1_n 26.0 23.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 5.0 26.0 37.0
# 139
# max J1 5.0 max J2 52.0 max J3 835774.5
# набор значений J1 по управлениям 1.0 2.0 16.5 u1_n 26.0 37.0 выглядит следующим образом: [5.0, 10.0, 15.0, 20.0]
# 20.0
# ...
# набор управлений агентов: 15.0 35.5 9.0
# 4077
# max J1 6982.26562 max J2 550.25 max J3 16949.25
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 35.5 9.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 35.5 23.0
# 4078
# max J1 6982.26562 max J2 550.25 max J3 282882.75
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 35.5 23.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 35.5 37.0
# 4079
# max J1 6982.26562 max J2 550.25 max J3 1177682.25
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 35.5 37.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 15.0 35.5 51.0
# 4080
# max J1 6982.26562 max J2 550.25 max J3 3084135.75
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 35.5 51.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# переходим к следующему шагу из-за J1
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 9.0
# 4081
# max J1 9309.6875 max J2 108.5 max J3 16949.25
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 7.0 9.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 9.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 23.0
# 4082
# max J1 9309.6875 max J2 108.5 max J3 282882.75
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 7.0 23.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 23.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 37.0
# 4083
# max J1 9309.6875 max J2 108.5 max J3 1177682.25
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 7.0 37.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 37.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 7.0 51.0
# 4084
# max J1 9309.6875 max J2 108.5 max J3 3084135.75
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 7.0 51.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 51.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 9.0
# 4085
# max J1 9309.6875 max J2 255.75 max J3 16949.25
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 16.5 9.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 9.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 23.0
# 4086
# max J1 9309.6875 max J2 255.75 max J3 282882.75
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 16.5 23.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 23.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 37.0
# 4087
# max J1 9309.6875 max J2 255.75 max J3 1177682.25
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 16.5 37.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 37.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 16.5 51.0
# 4088
# max J1 9309.6875 max J2 255.75 max J3 3084135.75
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 16.5 51.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 51.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 9.0
# 4089
# max J1 9309.6875 max J2 403.0 max J3 16949.25
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 26.0 9.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 9.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 23.0
# 4090
# max J1 9309.6875 max J2 403.0 max J3 282882.75
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 26.0 23.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 23.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 37.0
# 4091
# max J1 9309.6875 max J2 403.0 max J3 1177682.25
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 26.0 37.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 37.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 26.0 51.0
# 4092
# max J1 9309.6875 max J2 403.0 max J3 3084135.75
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 26.0 51.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 51.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# переходим к следующему шагу из-за J2
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 9.0
# 4093
# max J1 9309.6875 max J2 550.25 max J3 16949.25
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 35.5 9.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 9.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# набор значений J3 по управлениям 7.75 15.5 23.25 20.0 35.5 u3_n равен: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# переходим к следующему шагу из-за J3
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 23.0
# 4094
# max J1 9309.6875 max J2 550.25 max J3 282882.75
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 35.5 23.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 23.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# набор значений J3 по управлениям 7.75 15.5 23.25 20.0 35.5 u3_n равен: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# переходим к следующему шагу из-за J3
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 37.0
# 4095
# max J1 9309.6875 max J2 550.25 max J3 1177682.25
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 35.5 37.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 37.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# набор значений J3 по управлениям 7.75 15.5 23.25 20.0 35.5 u3_n равен: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# переходим к следующему шагу из-за J3
# False
# ******************************************************************
# набор управлений агентов: 20.0 35.5 51.0
# 4096
# max J1 9309.6875 max J2 550.25 max J3 3084135.75
# набор значений J1 по управлениям 7.75 15.5 23.25 u1_n 35.5 51.0 выглядит следующим образом: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# 9309.6875
# набор значений J2 по управлениям 7.75 15.5 23.25 20.0 u2_n 51.0 выглядит: [108.5, 255.75, 403.0, 550.25]
# набор значений J3 по управлениям 7.75 15.5 23.25 20.0 35.5 u3_n равен: [2327.42188, 4654.84375, 6982.26562, 9309.6875]
# значение z при оптимальных управлениях 788.70968
# True
# ******************************************************************
