# %%
#Штакельбер обычный - 1 агент
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import time
#start = time.time()

#объявление переменных
N = 10
T_min = 5000 #супервайзер u  (5000-7000)
T_max = 7000
tao_min = 0.1 #агент v
tao_max = 1

h_T = (T_max - T_min)/N
h_tao = (tao_max - tao_min)/N
z0 = 0.1
z_abs = 0.6 #то с чем сравниваем - наш показатель "эффективности" - идеальный 
a = 0.8 #коэфф
#m1 = 1 #коэфф
outlay = 0.007
lambd = - 100000
lambd_1 = -100 
salary = 10000
k_c = 7
bet = 0.5
#определяем функции - тестовые 
def J_0(T, tao, z):
    return (T * tao) * 0.8 * (1 - z) - outlay - lambd * (T ** lambd_1)
def J_1(T, tao, z):
    return 0.87 * salary * ((1 + z) ** 2) - tao * T * (1 - z) + k_c * (z**bet) * ((tao_max - tao)**(1 - bet))
def z_tao(tao):
    return round(z0 + a * tao, 5)


    
def Shtackelberg_1():    
    #цикл
    J0_list = []
    for i_T in range (N):
        T = T_min + i_T * h_T

        J1_list = []
        for i_tao in range (N):
            tao = tao_min + i_tao * h_tao
            J1_list.append(round(J_1(T, tao, z_tao(tao)), 7))
        J1_max = max(J1_list)
        tao_ind = round (J1_list.index(J1_max) * h_tao + tao_min, 7) #нашли tao при котором достигается максимум

        print("все значения функции ведомого для данного T", J1_list)
        print("max", max(J1_list)) 
        print("tao при котором max", tao_ind, "индекс этого элемента", J1_list.index(J1_max))
        print("значение показателя", z_tao(tao_ind))

        if z_tao(tao_ind) > z_abs:
            print("cool")
            J0_list.append(round(J_0(T, tao_ind, z_tao(tao_ind)), 7))
            print("значение z при оптимальном tao", z_tao(tao_ind) )
        else:
            print("fale") #если не выполняется уловие 4 мы должны поменять управление то есть просто переход не след.шаг цикла по Т
            continue 
        print(T) #из-за continue должен печатать только те T, которые удовлетворяют условию 4
        print("*************************************")
    print("все полученные значения J_0")   
    print(J0_list)  
    print('значение целевой функции супервайзера', max(J0_list))
    #print ('время выполнения программы:', time.time() - start, 'секунд')
    print('коэффициент согласованности', round(max(J0_list)/J_0(T_max, tao_max, z0), 5))
   
Shtackelberg_1()
# Out:
# все значения функции ведомого для данного T [11706.6974457, 12929.8473749, 14307.8721348, 15840.7955581, 17528.6277885, 19371.3706521, 21369.018478, 23521.5554088, 25828.9454316, 28291.0916846]
# max 28291.0916846
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 5000.0
# *************************************
# все значения функции ведомого для данного T [11690.2974457, 12901.4233749, 14270.0161348, 15796.0995581, 17479.6837885, 19320.7706521, 21319.354478, 23475.4194088, 25788.9294316, 28259.7876846]
# max 28259.7876846
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 5200.0
# *************************************
# все значения функции ведомого для данного T [11673.8974457, 12872.9993749, 14232.1601348, 15751.4035581, 17430.7397885, 19270.1706521, 21269.690478, 23429.2834088, 25748.9134316, 28228.4836846]
# max 28228.4836846
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 5400.0
# *************************************
# все значения функции ведомого для данного T [11657.4974457, 12844.5753749, 14194.3041348, 15706.7075581, 17381.7957885, 19219.5706521, 21220.026478, 23383.1474088, 25708.8974316, 28197.1796846]
# max 28197.1796846
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 5600.0
# *************************************
# все значения функции ведомого для данного T [11641.0974457, 12816.1513749, 14156.4481348, 15662.0115581, 17332.8517885, 19168.9706521, 21170.362478, 23337.0114088, 25668.8814316, 28165.8756846]
# max 28165.8756846
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 5800.0
# *************************************
# все значения функции ведомого для данного T [11624.6974457, 12787.7273749, 14118.5921348, 15617.3155581, 17283.9077885, 19118.3706521, 21120.698478, 23290.8754088, 25628.8654316, 28134.5716846]
# max 28134.5716846
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 6000.0
# *************************************
# все значения функции ведомого для данного T [11608.2974457, 12759.3033749, 14080.7361348, 15572.6195581, 17234.9637885, 19067.7706521, 21071.034478, 23244.7394088, 25588.8494316, 28103.2676846]
# max 28103.2676846
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 6200.0
# *************************************
# все значения функции ведомого для данного T [11591.8974457, 12730.8793749, 14042.8801348, 15527.9235581, 17186.0197885, 19017.1706521, 21021.370478, 23198.6034088, 25548.8334316, 28071.9636846]
# max 28071.9636846
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 6400.0
# *************************************
# все значения функции ведомого для данного T [11575.4974457, 12702.4553749, 14005.0241348, 15483.2275581, 17137.0757885, 18966.5706521, 20971.706478, 23152.4674088, 25508.8174316, 28040.6596846]
# max 28040.6596846
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 6600.0
# *************************************
# все значения функции ведомого для данного T [11559.0974457, 12674.0313749, 13967.1681348, 15438.5315581, 17088.1317885, 18915.9706521, 20922.042478, 23106.3314088, 25468.8014316, 28009.3556846]
# max 28009.3556846
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 6800.0
# *************************************
# все полученные значения J_0
# [626.073, 651.1162, 676.1594, 701.2026, 726.2458, 751.289, 776.3322, 801.3754, 826.4186, 851.4618]
# значение целевой функции супервайзера 851.4618
# коэффициент согласованности 0.16894
