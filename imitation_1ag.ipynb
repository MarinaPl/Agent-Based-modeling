# %%
#Штакельбер обычный - 1 агент
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import time
#start = time.time()

#объявление переменных
N = 10
T_min = 5000 #супервайзер u  (5000-7000)
T_max = 7000
tao_min = 0.1 #агент v
tao_max = 1

h_T = (T_max - T_min)/N
h_tao = (tao_max - tao_min)/N
z0 = 0.1
z_abs = 0.6 #то с чем сравниваем - наш показатель "эффективности" - идеальный 
a = 0.8 #коэфф
#m1 = 1 #коэфф
outlay = 0.007
lambd = - 100000
lambd_1 = -100 
salary = 10000
k_c = 7
bet = 1 #от 0.1 до 1 - смотрим зависимость к-та согласов. 
#определяем функции - тестовые 
def J_0(T, tao, z):
    return (T * tao) * 0.8 * (1 - z) - outlay - lambd * (T ** lambd_1)
def J_1(T, tao, z):
    return 0.87 * salary * ((1 + z) ** 2) - tao * T * (1 - z) + k_c * (z**bet) * ((tao_max - tao)**(1 - bet))
def z_tao(tao):
    return round(z0 + a * tao, 5)


    
def Shtackelberg_1():    
    #цикл
    J0_list = []
    for i_T in range (N):
        T = T_min + i_T * h_T

        J1_list = []
        for i_tao in range (N):
            tao = tao_min + i_tao * h_tao
            J1_list.append(round(J_1(T, tao, z_tao(tao)), 7))
        J1_max = max(J1_list)
        tao_ind = round (J1_list.index(J1_max) * h_tao + tao_min, 7) #нашли tao при котором достигается максимум

        print("все значения функции ведомого для данного T", J1_list)
        print("max", max(J1_list)) 
        print("tao при котором max", tao_ind, "индекс этого элемента", J1_list.index(J1_max))
        print("значение показателя", z_tao(tao_ind))

        if z_tao(tao_ind) > z_abs:
            print("cool")
            J0_list.append(round(J_0(T, tao_ind, z_tao(tao_ind)), 7))
            print("значение z при оптимальном tao", z_tao(tao_ind) )
        else:
            print("fale") #если не выполняется уловие 4 мы должны поменять управление то есть просто переход не след.шаг цикла по Т
            continue 
        print(T) #из-за continue должен печатать только те T, которые удовлетворяют условию 4
        print("*************************************")
    print("все полученные значения J_0")   
    print(J0_list)  
    print('значение целевой функции супервайзера', max(J0_list))
    #print ('время выполнения программы:', time.time() - start, 'секунд')
    print('коэффициент согласованности', round(max(J0_list)/J_0(T_max, tao_max, z0), 5))
   
Shtackelberg_1()
# Out:
# все значения функции ведомого для данного T [11705.14, 12928.4488, 14306.7592, 15840.0712, 17528.3848, 19371.7, 21370.0168, 23523.3352, 25831.6552, 28294.9768]
# max 28294.9768
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 5000.0
# *************************************
# все значения функции ведомого для данного T [11688.74, 12900.0248, 14268.9032, 15795.3752, 17479.4408, 19321.1, 21320.3528, 23477.1992, 25791.6392, 28263.6728]
# max 28263.6728
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 5200.0
# *************************************
# все значения функции ведомого для данного T [11672.34, 12871.6008, 14231.0472, 15750.6792, 17430.4968, 19270.5, 21270.6888, 23431.0632, 25751.6232, 28232.3688]
# max 28232.3688
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 5400.0
# *************************************
# все значения функции ведомого для данного T [11655.94, 12843.1768, 14193.1912, 15705.9832, 17381.5528, 19219.9, 21221.0248, 23384.9272, 25711.6072, 28201.0648]
# max 28201.0648
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 5600.0
# *************************************
# все значения функции ведомого для данного T [11639.54, 12814.7528, 14155.3352, 15661.2872, 17332.6088, 19169.3, 21171.3608, 23338.7912, 25671.5912, 28169.7608]
# max 28169.7608
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 5800.0
# *************************************
# все значения функции ведомого для данного T [11623.14, 12786.3288, 14117.4792, 15616.5912, 17283.6648, 19118.7, 21121.6968, 23292.6552, 25631.5752, 28138.4568]
# max 28138.4568
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 6000.0
# *************************************
# все значения функции ведомого для данного T [11606.74, 12757.9048, 14079.6232, 15571.8952, 17234.7208, 19068.1, 21072.0328, 23246.5192, 25591.5592, 28107.1528]
# max 28107.1528
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 6200.0
# *************************************
# все значения функции ведомого для данного T [11590.34, 12729.4808, 14041.7672, 15527.1992, 17185.7768, 19017.5, 21022.3688, 23200.3832, 25551.5432, 28075.8488]
# max 28075.8488
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 6400.0
# *************************************
# все значения функции ведомого для данного T [11573.94, 12701.0568, 14003.9112, 15482.5032, 17136.8328, 18966.9, 20972.7048, 23154.2472, 25511.5272, 28044.5448]
# max 28044.5448
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 6600.0
# *************************************
# все значения функции ведомого для данного T [11557.54, 12672.6328, 13966.0552, 15437.8072, 17087.8888, 18916.3, 20923.0408, 23108.1112, 25471.5112, 28013.2408]
# max 28013.2408
# tao при котором max 0.91 индекс этого элемента 9
# значение показателя 0.828
# cool
# значение z при оптимальном tao 0.828
# 6800.0
# *************************************
# все полученные значения J_0
# [626.073, 651.1162, 676.1594, 701.2026, 726.2458, 751.289, 776.3322, 801.3754, 826.4186, 851.4618]
# значение целевой функции супервайзера 851.4618
# коэффициент согласованности 0.16894
